# %% [markdown]
# # Algorithm 1: Estimation of $u^\top f(A) u$
# ## Graphs
# Plots to observe the convergence of the method presented as algo in the paper.

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matrices import * 
from helpers import *

# %% [markdown]
# #### Poisson matrix
# n = 900

# %%
poisson_matrix=Poisson_function(30) 
n = 900
u = np.zeros(n)
u[0] = 1
graph_algo1(poisson_matrix, u, matrix_label='Poisson Matrix', savefile='poisson_matrix')

# %% [markdown]
# #### VHF matrix
# n = 625

# %%
#modified version to be able to see the values of the eigenvalues
VFH_matrix = -VFH_function(4)
n = 625
u = np.zeros(n)
u[0] = 1
graph_algo1(VFH_matrix, u, matrix_label='VFH Matrix', savefile='VHF_matrix')

# %% [markdown]
# #### Wathen matrix
# n = 481

# %%
nx=12
ny=12 #as in the paper
wathen_matrix=wathen_ge(nx, ny)
n = 481
u = np.zeros(n)
u[0] = 1
graph_algo1(wathen_matrix, u, matrix_label='Wathen Matrix', savefile='wathen_matrix')

# %% [markdown]
# #### Lehmer matrix
# n = 200

# %%
lehmer_matrix=Lehmer_function(200) #as in the paper
n = lehmer_matrix.shape[0]
u = np.zeros(n)
u[0] = 1
graph_algo1(lehmer_matrix, u, matrix_label='Lehmer Matrix', savefile='lehmer_matrix')

# %% [markdown]
# #### Pei matrix

# %%
alpha=1
n=300 #as in the paper
pei_matrix=Pei_function(alpha, n)
n = pei_matrix.shape[0]
u = np.zeros(n)
u[0] = 1
graph_algo1(pei_matrix, u, matrix_label='Pei Matrix', savefile='pei_matrix')

# %% [markdown]
# #### Heat flow matrix

# %%
N=30 #hence has final size 900 as in the paper
nu=0.2 
heat_flow_matrix=heat_flow_function(nu,N)

n = heat_flow_matrix.shape[0]
u = np.zeros(n)
u[0] = 1
graph_algo1(heat_flow_matrix, u, matrix_label='Heat Flow Matrix', savefile='heat_flow_matrix')
