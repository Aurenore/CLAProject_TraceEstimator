# %% [markdown]
# # Algorithm 2: graphs

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matrices import * 
from scipy.linalg import block_diag
from helpers import *

# %% [markdown]
# ## Trace estimation
# Numerical results of the Monte Carlo approach (Algorithm 2) for estimating $tr(A^{-1})$.
# #### Poisson matrix
# n = 900

# %%
def f(x):
        return 1/x
Ms = np.arange(1, 50)

# %%
poisson_matrix=Poisson_function(30) 
I_ex = np.trace(np.linalg.inv(poisson_matrix))
graph(poisson_matrix, Ms, f, I_ex, matrixlabel='Poisson Matrix', savefile='poisson_matrix_trace', ylabel='Trace')
# Out:
# k = 0
# k = 10
# k = 20

# %% [markdown]
# #### VHF matrix
# n = 625

# %%
#modified version to be able to see the values of the eigenvalues
VFH_matrix = -VFH_function(4)
I_ex = np.trace(np.linalg.inv(VFH_matrix))
graph(VFH_matrix, Ms, f, I_ex, matrixlabel='VFH Matrix', savefile='VHF_matrix_trace', ylabel='Trace')
# Out:
# k = 0
# k = 10
# k = 20
# k = 30
# k = 40

# %% [markdown]
# #### Wathen matrix
# n = 481

# %%
nx=12
ny=12 #as in the paper
wathen_matrix=wathen_ge(nx, ny)

I_ex = np.trace(np.linalg.inv(wathen_matrix))
graph(wathen_matrix, Ms, f, I_ex, matrixlabel='Wathen Matrix', savefile='wathen_matrix_trace', ylabel='Trace')
# Out:
# k = 0
# k = 10
# k = 20
# k = 30
# k = 40

# %% [markdown]
# #### Lehmer matrix
# n = 200

# %%
lehmer_matrix=Lehmer_function(200) #as in the paper

I_ex = np.trace(np.linalg.inv(lehmer_matrix))
graph(lehmer_matrix, Ms, f, I_ex, matrixlabel='Lehmer Matrix', savefile='lehmer_matrix_trace', ylabel='Trace')
# Out:
# k = 0
# k = 10
# k = 20
# k = 30
# k = 40

# %% [markdown]
# #### Pei matrix

# %%
alpha=1
n=300 #as in the paper
pei_matrix=Pei_function(alpha, n)

I_ex = np.trace(np.linalg.inv(pei_matrix))
graph(pei_matrix, Ms, f, I_ex, matrixlabel='Pei Matrix', savefile='pei_matrix_trace', ylabel='Trace')
# Out:
# k = 0
# k = 10
# k = 20
# k = 30
# k = 40

# %% [markdown]
# #### Heat flow matrix

# %%
N=30 #hence has final size 900 as in the paper
nu=0.2 
heat_flow_matrix=heat_flow_function(nu,N)

I_ex = np.trace(np.linalg.inv(heat_flow_matrix))
graph(heat_flow_matrix, Ms, f, I_ex, matrixlabel='Heat Flow Matrix', savefile='heat_flow_matrix_trace', ylabel='Trace')
# Out:
# k = 0
# k = 10
# k = 20
# k = 30
# k = 40
