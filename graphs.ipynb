# %%
import numpy as np 
import matplotlib.pyplot as plt
#for part e)
from matrices import * 
import time 
from scipy.linalg import block_diag
from helpers import *

# %%
#Poisson matrix
poisson_matrix=Poisson_function(30) 
Ms = np.arange(1, 50)
graph(poisson_matrix, Ms) #error below because i forgot something... but the plot gives an idea of the result (took 30 min to run)...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_66104/239243442.py in <module>
#       2 poisson_matrix=Poisson_function(30)
#       3 Ms = np.arange(1, 50)
# ----> 4 graph(poisson_matrix, Ms)
#
# ~\AppData\Local\Temp/ipykernel_66104/456219603.py in graph(matrix, Ms)
#      29     plt.xlabel('Number of samples')
#      30     plt.ylabel('Trace')
# ---> 31     plt.title('Matrix of size ', n, 'x', n)
#      32
#      33
#
# c:\Users\anyam\.conda\envs\adaexam\lib\site-packages\matplotlib\pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3010 @_copy_docstring_and_deprecators(Axes.set_title)
#    3011 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
# -> 3012     return gca().set_title(
#    3013         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    3014
#
# ...
