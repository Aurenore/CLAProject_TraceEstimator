# %% [markdown]
# # Algorithm 2: graphs

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matrices import * 
from scipy.linalg import block_diag
from helpers import *

# %% [markdown]
# ## Trace estimation
# Numerical results of the Monte Carlo approach (Algorithm 2) for estimating $tr(A^{-1})$.
# #### Poisson matrix
# n = 900

# %%
def f(x):
        return 1/x
Ms = np.arange(1, 5)

# %%
poisson_matrix=Poisson_function(30) 
I_ex = np.trace(np.linalg.inv(poisson_matrix))
graph(poisson_matrix, Ms, f, I_ex, matrixlabel='Poisson Matrix', savefile='poisson_matrix_trace', ylabel='Trace')
# Out:
# k = 0

# %% [markdown]
# #### VHF matrix
# n = 625

# %%
VFH_matrix = VFH_function(4)
print(np.linalg.eig(VFH_matrix)[1]>0)
I_ex = np.trace(np.linalg.inv(VFH_matrix))
graph(VFH_matrix, Ms, f, I_ex, matrixlabel='VFH Matrix', savefile='VHF_matrix_trace', ylabel='Trace')
# Out:
# [[False False  True ...  True False  True]
#  [ True False  True ...  True False  True]
#  [ True False  True ... False  True False]
#  ...
#  [False False False ...  True  True False]
#  [False  True  True ... False False False]
#  [False False False ...  True False  True]]
# k = 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(np.linalg.eig(VFH_matrix)[1]>0)
#       3 I_ex = np.trace(np.linalg.inv(VFH_matrix))
# ----> 4 graph(VFH_matrix, Ms, f, I_ex, matrixlabel='VFH Matrix', savefile='VHF_matrix_trace', ylabel='Trace')
#
# File c:\Users\anyam\Desktop\Computational Linear Algebra\Project\CLAProject_TraceEstimator\helpers.py:322, in graph(matrix, Ms, f, I_ex, matrixlabel, savefile, ylabel)
#     320     if k%10==0:
#     321         print("k =", k)
# --> 322     U_p[k], L_p[k], I[k] = algorithm_2(matrix, m=m, p=0.95, function=f, epsilon=tol)
#     324 fig = plt.figure(figsize=(8,8))
#     325 plt.plot(Ms, I_ex*np.ones(len(Ms)))
#
# File c:\Users\anyam\Desktop\Computational Linear Algebra\Project\CLAProject_TraceEstimator\helpers.py:201, in algorithm_2(A, m, p, function, epsilon)
#     198     raise ValueError('The matrix isnt symmetric')
#     200 if np.any(np.linalg.eigvals(A) <= 0):
# --> 201     raise ValueError('The matrix isnt positive definite')
#     203 if p<=0 or p>=1:
#     204     raise ValueError('we dont have 0<p<1')
#
# ValueError: The matrix isnt positive definite

# %% [markdown]
# #### Wathen matrix
# n = 481

# %%
nx=12
ny=12 #as in the paper
wathen_matrix=wathen_ge(nx, ny)

I_ex = np.trace(np.linalg.inv(wathen_matrix))
graph(wathen_matrix, Ms, f, I_ex, matrixlabel='Wathen Matrix', savefile='wathen_matrix_trace', ylabel='Trace')
# Out:
# k = 0

# %% [markdown]
# #### Lehmer matrix
# n = 200

# %%
lehmer_matrix=Lehmer_function(200) #as in the paper

I_ex = np.trace(np.linalg.inv(lehmer_matrix))
graph(lehmer_matrix, Ms, f, I_ex, matrixlabel='Lehmer Matrix', savefile='lehmer_matrix_trace', ylabel='Trace')
# Out:
# k = 0
