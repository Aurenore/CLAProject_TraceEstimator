# %%
import numpy as np 
import matplotlib.pyplot as plt
#for part e)
from matrices import * 
import time 
from scipy.linalg import block_diag
from helpers import *

# %% [markdown]
# ### Trace

# %%
#Poisson matrix
def f(x):
        return 1/x

poisson_matrix=Poisson_function(30) 
I_ex = np.trace(np.linalg.inv(poisson_matrix))
Ms = np.arange(1, 5)
graph(poisson_matrix, Ms, f, I_ex, matrixlabel='Poisson Matrix', savefile='poisson_matrix_trace', ylabel='Trace')
# Out:
# k = 0

# %% [markdown]
# ### Det(A)

# %%
def f(x):
    return np.log(x)

poisson_matrix=Poisson_function(30) 
I_ex=np.linalg.slogdet(poisson_matrix)[1]
Ms = np.arange(1, 5)
graph(poisson_matrix, Ms, f, I_ex, matrixlabel='Poisson Matrix', savefile='poisson_matrix_logdet', ylabel='Trace of log of matrix')
# Out:
# k = 0
